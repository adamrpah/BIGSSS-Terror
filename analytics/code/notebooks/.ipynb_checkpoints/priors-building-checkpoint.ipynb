# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
tdf = pd.read_csv('../../data/country_gtd.csv', index_col=0)
tdf = tdf[(tdf.iyear>=2001) & (tdf.iyear <= 2005)]
print(len(tdf),  len(tdf[tdf.gname == 'Unknown']) )
tdf = tdf[tdf.gname != 'Unknown']
tdf.nkill.fillna(0, inplace=True)
tdf.head()
# Out:
# /Users/adampah/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,7,18,19,32,34,62,63,65,73,76,79,94,96,114,115,121,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 1962 1039
#             eventid  iyear  imonth  iday         approxdate  extended  \
# 22024  200101000001   2001       1     0  January 8-9, 2001         0
# 22026  200101010002   2001       1     1                NaN         1
# 22035  200101030006   2001       1     3                NaN         0
# 22041  200101050006   2001       1     5                NaN         0
# 22045  200101060001   2001       1     6                NaN         0
#
#        resolution  country country_txt  region   ...     \
# 22024         NaN       45    Colombia       3   ...
# 22026  2001-01-07       45    Colombia       3   ...
# 22035         NaN       45    Colombia       3   ...
# 22041         NaN       45    Colombia       3   ...
# 22045         NaN       45    Colombia       3   ...
#
#                                                 addnotes  \
# 22024  Sources imply that the attack may have taken p...
# 22026  The fate of the seven hostages not released wi...
# 22035                                                NaN
# 22041  Sources provide different locations for the in...
# 22045  The Caño Limón-Coveñas pipeline travels 780 ki...
#
#                                                   scite1  \
# 22024  "Twenty murdered in attacks across Colombia at...
# 22026  “Colombia – Kidnapping 17 Kidnap Victims Freed...
# 22035  "At least 11 murdered in northwest Colombia," ...
# 22041  "Thirteen die in second regional massacre," As...
# 22045  Center For Terrorism and Intelligence Studies,...
#
#                                                   scite2  \
# 22024  "Colombia violence leaves 35 dead," Agence Fra...
# 22026  “Paramilitary Group Releases 17 Peasants it Ca...
# 22035  "Eleven killed in northwestern Colombia town,"...
# 22041  "Twelve dead in second Colombia massacre in tw...
# 22045  “Rebels Sabotage Cano Limon Pipeline,” Busines...
#
#                                                   scite3         dbsource  \
# 22024                                                NaN  UMD Schmid 2012
# 22026                                                NaN            CETIS
# 22035  Michael Easterbrook, "Colombia envoy on missio...  UMD Schmid 2012
# 22041  "Twelve Colombian farm workers killed - parami...  UMD Schmid 2012
# 22045  “ELN Blaimed for Cano-Limon Pipeline Attack,” ...            CETIS
#
#        INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 22024       -9        -9        0      -9      NaN
# 22026        0         0        0       0      NaN
# 22035       -9        -9        0      -9      NaN
# 22041        0         0        0       0      NaN
# 22045        0         1        1       1      NaN
#
# [5 rows x 134 columns]

# %%
gtd2philips = dict(pd.read_csv('../../data/translation.csv', header=None).values.tolist())
    
philips2gtd = {}
for k,v in gtd2philips.items():
    if v not in philips2gtd:
        philips2gtd[v] = k
    else:
        pass

# %%
for k,v in philips2gtd.items():
    try:
        if 'tawhid' in k.lower() or ' land ' in k.lower():
            print(k, '----', v)
    except AttributeError:
        pass
# Out:
# al-Qaeda Organization in the Land of the Two Rivers ---- al-Qaeda Organization in the Land of the Two Rivers
# Islamic Glory Brigades in the Land of the Nile ---- Islamic Glory Brigades in the Land of the Nile
# Tawhid and Jihad ---- Tawhid and Jihad
# Tawhid Islamic Brigades ---- Tawhid Islamic Brigades

# %%
tdf.attacktype2.unique()
# Out:
# array([ nan,   7.,   2.,   6.,   3.,   1.])

# %%
for gname in tdf.gname.unique():
    if 'tawhid' in gname.lower() or ' rivers ' in gname.lower():
        print(gname)
# Out:
# Tawhid and Jihad

# %% [markdown]
# # Get to capacity from:
#
# number casualties (log-mean)
#
# number of weapons types
#
# number of attack types

# %%
def condense_columns(columns, df, cfname):
    groupdata = []
    for (gname, country), groupdf in df.groupby(['gname', 'country_txt']):
        typelist = []
        for c in columns:
            typelist.extend(groupdf[c].values.tolist())
        unique_types = [x for x in list(set(typelist)) if np.isnan(x)==False]
        groupdata.append([gname, country, len(unique_types)])
    return pd.DataFrame(groupdata, columns = ['gname', 'country_txt', cfname])

def clean_names(x, final_name, input_names):
    if x in input_names:
        return final_name
    else:
        return x
    
    
#We need to clean the groupnames

tdf['gname'] = tdf['gname'].apply(lambda x: clean_names(x, 'AQI', ['Tawhid and Jihad', 'Al-Qa`ida in Iraq']))
tdf['gname'] = tdf['gname'].apply(lambda x: clean_names(x, 'Al-Qaeda', ['Al-Qa`ida']))
#First we need to make the log nkills
tdf['lognkill'] = tdf.nkill.apply(lambda x: np.log(x+1))
#Now we get the basic information
base_stats_df = tdf.groupby(['gname', 'country_txt']).agg({'lognkill':'mean', 'eventid':'count'}).reset_index()
#Now we get the attack types
attack_type_df = condense_columns(['attacktype1', 'attacktype2', 'attacktype3'], tdf, 'attack_types')
#Now we get the weapon types
weapon_type_df = condense_columns(['weaptype1', 'weaptype2', 'weaptype3', 'weaptype4'], tdf, 'weapon_types')
#Now I merge the weapon and attacks
attr_df = pd.merge(attack_type_df, weapon_type_df, on=['gname', 'country_txt'])
#Now I merge it all
group_attr = pd.merge(base_stats_df, attr_df, on=['gname', 'country_txt'])
group_attr
# Out:
#                                                 gname  country_txt  lognkill  \
# 0                            1920 Revolution Brigades         Iraq  2.138333
# 1                                                 AQI         Iraq  1.826740
# 2                          Abu Hafs al-Masri Brigades         Iraq  2.079442
# 3                               Al Zawahiri Loyalists         Iraq  0.000000
# 4                                            Al-Qaeda  Afghanistan  0.973233
# 5                                        Ansar al-Din         Iraq  0.000000
# 6                                      Ansar al-Islam         Iraq  2.191229
# 7                                      Ansar al-Jihad         Iraq  0.000000
# 8                                      Ansar al-Sunna         Iraq  1.822406
# 9           Armed Vanguards of a Second Mohammed Army         Iraq  3.218876
# 10                                      Badr Brigades         Iraq  1.098612
# 11                   Brigades of Iman Hassan-al-Basri         Iraq  1.386294
# 12  Civil Association for Peace in Colombia, Asocipaz     Colombia  2.302585
# 13                                        Death Squad     Colombia  1.956012
# 14                                             Gunmen     Colombia  0.735608
# 15                                             Gunmen         Iraq  0.000000
# 16                                      Hizb-I-Islami  Afghanistan  0.231049
# 17                       Holders of the Black Banners         Iraq  0.000000
# 18                               Imam Hussein Brigade         Iraq  0.895880
# 19                                         Individual         Iraq  0.693147
# 20  Islamic Army in Iraq (al-Jaish al-Islami fi al...         Iraq  1.141087
# 21                             Islamic Jihad Brigades         Iraq  0.000000
# 22                Islamic Movement of Iraqi Mujahidin         Iraq  0.693147
# 23                                Islamist Extremists  Afghanistan  1.386294
# 24                         Jaish al-Ta'ifa al-Mansura         Iraq  1.039721
# 25            Jaysh al-Muslimin (Army of the Muslims)  Afghanistan  0.000000
# 26                          Junaid Jihadist Battalion         Iraq  0.000000
# 27                           Khalid ibn Walid Brigade         Iraq  0.000000
# 28                     Kurdistan Workers' Party (PKK)         Iraq  2.079442
# 29                               Left-Wing Extremists     Colombia  1.051499
# 30                               Left-Wing Guerrillas     Colombia  1.609438
# 31                                Liberals of Galilee         Iraq  0.000000
# 32                                         Mahdi Army         Iraq  0.000000
# 33                                    Mujahedeen Army         Iraq  0.000000
# 34                                Mujahedeen Brigades         Iraq  0.000000
# 35                           Mujahedeen Corps in Iraq         Iraq  0.000000
# 36                                   Mujahedeen Group         Iraq  2.197225
# 37                           Mujahedeen Shura Council         Iraq  0.000000
# 38         National Liberation Army of Colombia (ELN)     Colombia  0.224306
# 39                             Omar Bin Khattab Group         Iraq  0.000000
# 40                                   Opposition Group  Afghanistan  0.000000
# 41                                              Other  Afghanistan  0.946047
# 42                                              Other     Colombia  0.346574
# 43                                              Other         Iraq  1.778479
# 44                                     Paramilitaries     Colombia  2.142920
# 45                  People's Revolutionary Army (ERP)     Colombia  0.077016
# 46                      Popular Liberation Army (EPL)     Colombia  0.831777
# 47                        Protectors of Islam Brigade         Iraq  0.000000
# 48                                             Rebels     Colombia  0.346574
# 49      Revolutionary Armed Forces of Colombia (FARC)     Colombia  0.766673
# 50                             Right-Wing Death Squad     Colombia  1.791759
# 51                          Right-Wing Paramilitaries     Colombia  1.890238
# 52                                  Saif-ul-Muslimeen  Afghanistan  0.000000
# 53  Supreme Council for Islamic Revolution in Iraq...         Iraq  0.000000
# 54      Takfir wal-Hijra (Excommunication and Exodus)         Iraq  2.564949
# 55                                            Taliban  Afghanistan  0.906015
# 56                                      Tela Mohammed  Afghanistan  0.000000
# 57        United Self Defense Units of Colombia (AUC)     Colombia  1.461448
#
#     eventid  attack_types  weapon_types
# 0         2             1             1
# 1       120             6             5
# 2         1             1             1
# 3         1             1             1
# 4        19             3             2
# 5         1             1             1
# 6         7             2             2
# 7         1             1             1
# 8        16             4             5
# 9         1             1             1
# 10        1             2             1
# 11        1             1             1
# 12        1             1             1
# 13        2             2             2
# 14       15             3             2
# 15        1             2             1
# 16        6             2             2
# 17        1             2             1
# 18        2             2             2
# 19        1             1             1
# 20        4             4             3
# 21        1             1             1
# 22        1             1             1
# 23        1             1             1
# 24        2             2             2
# 25        2             2             2
# 26        1             1             1
# 27        1             1             1
# 28        1             1             1
# 29        5             2             1
# 30        1             1             1
# 31        1             1             1
# 32        3             1             4
# 33        1             1             1
# 34        1             1             2
# 35        1             1             2
# 36        1             2             3
# 37        2             2             3
# 38       87             6             4
# 39        1             1             1
# 40        5             1             1
# 41        4             1             1
# 42        2             2             2
# 43        9             4             4
# 44        4             2             2
# 45        9             2             2
# 46        5             4             3
# 47        1             1             1
# 48        4             3             4
# 49      276             8             8
# 50        1             2             1
# 51        6             5             4
# 52        1             1             1
# 53        3             2             2
# 54        1             1             1
# 55      235             6             5
# 56        1             1             1
# 57       38             6             5

# %%
group_attr.plot(kind='scatter', x='weapon_types', y='attack_types')

group_attr['weapon_types'].corr(group_attr['attack_types'])
# Out:
# 0.89302424641428702

# %%
group_attr.plot(kind='scatter', x='weapon_types', y='lognkill')

group_attr['weapon_types'].corr(group_attr['lognkill'])
# Out:
# 0.11244958340416022

# %%
group_attr.plot(kind='scatter', x='attack_types', y='lognkill')

group_attr['attack_types'].corr(group_attr['lognkill'])
# Out:
# 0.15542007639130215

# %% [markdown]
# # And now for the regression

# %%
import statsmodels.formula.api as smf

fitmodel = smf.ols(formula='lognkill ~ attack_types -1', data=group_attr).fit()
fitmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               lognkill   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     36.73
# Date:                Fri, 27 Jul 2018   Prob (F-statistic):           1.14e-07
# Time:                        15:06:27   Log-Likelihood:                -80.608
# No. Observations:                  58   AIC:                             163.2
# Df Residuals:                      57   BIC:                             165.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# attack_types     0.2897      0.048      6.061      0.000       0.194       0.385
# ==============================================================================
# Omnibus:                        5.916   Durbin-Watson:                   1.706
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                5.549
# Skew:                           0.757   Prob(JB):                       0.0624
# Kurtosis:                       3.045   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
mult = ( group_attr.eventid.mean()/(365*4 + 1) / group_attr.lognkill.mean() )* 0.8
group_attr['mu'] = group_attr.attack_types.apply(lambda gx: fitmodel.params['attack_types'] * mult * gx)
# Out:
#                                                 gname  lognkill  eventid  \
# 0                            1920 Revolution Brigades  2.138333        2
# 1                                                 AQI  1.826740      120
# 2                          Abu Hafs al-Masri Brigades  2.079442        1
# 3                               Al Zawahiri Loyalists  0.000000        1
# 4                                            Al-Qaeda  0.973233       19
# 5                                        Ansar al-Din  0.000000        1
# 6                                      Ansar al-Islam  2.191229        7
# 7                                      Ansar al-Jihad  0.000000        1
# 8                                      Ansar al-Sunna  1.822406       16
# 9           Armed Vanguards of a Second Mohammed Army  3.218876        1
# 10                                      Badr Brigades  1.098612        1
# 11                   Brigades of Iman Hassan-al-Basri  1.386294        1
# 12  Civil Association for Peace in Colombia, Asocipaz  2.302585        1
# 13                                        Death Squad  1.956012        2
# 14                                             Gunmen  0.689632       16
# 15                                      Hizb-I-Islami  0.231049        6
# 16                       Holders of the Black Banners  0.000000        1
# 17                               Imam Hussein Brigade  0.895880        2
# 18                                         Individual  0.693147        1
# 19  Islamic Army in Iraq (al-Jaish al-Islami fi al...  1.141087        4
# 20                             Islamic Jihad Brigades  0.000000        1
# 21                Islamic Movement of Iraqi Mujahidin  0.693147        1
# 22                                Islamist Extremists  1.386294        1
# 23                         Jaish al-Ta'ifa al-Mansura  1.039721        2
# 24            Jaysh al-Muslimin (Army of the Muslims)  0.000000        2
# 25                          Junaid Jihadist Battalion  0.000000        1
# 26                           Khalid ibn Walid Brigade  0.000000        1
# 27                     Kurdistan Workers' Party (PKK)  2.079442        1
# 28                               Left-Wing Extremists  1.051499        5
# 29                               Left-Wing Guerrillas  1.609438        1
# 30                                Liberals of Galilee  0.000000        1
# 31                                         Mahdi Army  0.000000        3
# 32                                    Mujahedeen Army  0.000000        1
# 33                                Mujahedeen Brigades  0.000000        1
# 34                           Mujahedeen Corps in Iraq  0.000000        1
# 35                                   Mujahedeen Group  2.197225        1
# 36                           Mujahedeen Shura Council  0.000000        2
# 37         National Liberation Army of Colombia (ELN)  0.224306       87
# 38                             Omar Bin Khattab Group  0.000000        1
# 39                                   Opposition Group  0.000000        5
# 40                                              Other  1.365577       15
# 41                                     Paramilitaries  2.142920        4
# 42                  People's Revolutionary Army (ERP)  0.077016        9
# 43                      Popular Liberation Army (EPL)  0.831777        5
# 44                        Protectors of Islam Brigade  0.000000        1
# 45                                             Rebels  0.346574        4
# 46      Revolutionary Armed Forces of Colombia (FARC)  0.766673      276
# 47                             Right-Wing Death Squad  1.791759        1
# 48                          Right-Wing Paramilitaries  1.890238        6
# 49                                  Saif-ul-Muslimeen  0.000000        1
# 50  Supreme Council for Islamic Revolution in Iraq...  0.000000        3
# 51      Takfir wal-Hijra (Excommunication and Exodus)  2.564949        1
# 52                                            Taliban  0.906015      235
# 53                                      Tela Mohammed  0.000000        1
# 54        United Self Defense Units of Colombia (AUC)  1.461448       38
#
#     attack_types  weapon_types        mu
# 0              1             1  0.001814
# 1              6             5  0.010883
# 2              1             1  0.001814
# 3              1             1  0.001814
# 4              3             2  0.005442
# 5              1             1  0.001814
# 6              2             2  0.003628
# 7              1             1  0.001814
# 8              4             5  0.007256
# 9              1             1  0.001814
# 10             2             1  0.003628
# 11             1             1  0.001814
# 12             1             1  0.001814
# 13             2             2  0.003628
# 14             4             2  0.007256
# 15             2             2  0.003628
# 16             2             1  0.003628
# 17             2             2  0.003628
# 18             1             1  0.001814
# 19             4             3  0.007256
# 20             1             1  0.001814
# 21             1             1  0.001814
# 22             1             1  0.001814
# 23             2             2  0.003628
# 24             2             2  0.003628
# 25             1             1  0.001814
# 26             1             1  0.001814
# 27             1             1  0.001814
# 28             2             1  0.003628
# 29             1             1  0.001814
# 30             1             1  0.001814
# 31             1             4  0.001814
# 32             1             1  0.001814
# 33             1             2  0.001814
# 34             1             2  0.001814
# 35             2             3  0.003628
# 36             2             3  0.003628
# 37             6             4  0.010883
# 38             1             1  0.001814
# 39             1             1  0.001814
# 40             5             5  0.009069
# 41             2             2  0.003628
# 42             2             2  0.003628
# 43             4             3  0.007256
# 44             1             1  0.001814
# 45             3             4  0.005442
# 46             8             8  0.014511
# 47             2             1  0.003628
# 48             5             4  0.009069
# 49             1             1  0.001814
# 50             2             2  0.003628
# 51             1             1  0.001814
# 52             6             5  0.010883
# 53             1             1  0.001814
# 54             6             5  0.010883
